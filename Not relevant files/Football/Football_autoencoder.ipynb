# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import networkx.generators as gen
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torch.nn.functional as F
import networkx as nx
from sklearn.cluster import KMeans
from sklearn import metrics
from networkx.algorithms.community import greedy_modularity_communities
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
filename = 'football.gml'
G_data = nx.read_gml(filename)
B_data = nx.modularity_matrix(G_data)

# %%
# Train test split here batch size=train_ds
def givetrain(inputs,targets):  
  train_ds = TensorDataset(inputs, targets)
  train_dl=DataLoader(train_ds,batch_size=len(train_ds))
  return train_dl

# %%
# Test The data
print(B_data.shape,len(G_data.edges()))
# Out:
# (115, 115) 613

# %%
class AE(nn.Module):
    def __init__(self,in_layers,hidden_layers):
        super().__init__()
        # Encoder
        self.encoder_hidden_layer = nn.Linear(
            in_features=in_layers, out_features=hidden_layers
        )
        self.encoder_output_layer = nn.Linear(
            in_features=hidden_layers, out_features=hidden_layers
        )
        # DEcoder
        self.decoder_hidden_layer= nn.Linear(
            in_features=hidden_layers, out_features=hidden_layers
        )
        self.decoder_output_layer = nn.Linear(
            in_features=hidden_layers, out_features=in_layers
        )

    def forward(self, features):
        activation = self.encoder_hidden_layer(features)
        activation = torch.tanh(activation)
        # activation = nn.Dropout(p=0.01)(activation)
        code = self.encoder_output_layer(activation)
        code = torch.tanh(code)
        # code = nn.Dropout(p=0.01)(code)
        encoder=code
        activation = self.decoder_hidden_layer(code)
        activation = torch.tanh(activation)
        # activation = nn.Dropout(p=0.01)(activation)
        activation = self.decoder_output_layer(activation)
        reconstructed = torch.tanh(activation)
        # reconstructed = nn.Dropout(p=0.01)(reconstructed)
        return encoder,reconstructed

# %%
epochs = 1000
learning_rate = 1e-3

# %%
#  use gpu if available
device = torch.device("cpu")

# create a model from `AE` autoencoder class
# load it to the specified device, either gpu or cpu
model1 = AE(hidden_layers=64,in_layers=B_data.shape[0]).to(device)
model2=AE(hidden_layers=32,in_layers=64).to(device)
model3=AE(hidden_layers=16,in_layers=32).to(device)
# create an optimizer object
# Adam optimizer with learning rate 1e-3
optimizer1 = optim.Adam(model1.parameters(), lr=learning_rate)
optimizer2 = optim.Adam(model2.parameters(), lr=learning_rate)
optimizer3 = optim.Adam(model3.parameters(), lr=learning_rate)

# mean-squared error loss
def loss_func(input,target):
  return F.mse_loss(input,target)
print(model2)
# Out:
# AE(
#   (encoder_hidden_layer): Linear(in_features=64, out_features=32, bias=True)
#   (encoder_output_layer): Linear(in_features=32, out_features=32, bias=True)
#   (decoder_hidden_layer): Linear(in_features=32, out_features=32, bias=True)
#   (decoder_output_layer): Linear(in_features=32, out_features=64, bias=True)
# )

# %%
def train_model(epochs,train_dl,model,optimizer,fl=0):
  enc,out=0,0
  hist=[]
  for epoch in range(epochs):
    loss = 0
    for batch_features, _ in train_dl:
      # reset the gradients back to zero
      # PyTorch accumulates gradients on subsequent backward passes
        # optimizer.zero_grad()
        optimizer.zero_grad()
        # compute reconstructions
        encoder,outputs = model(batch_features.float())
        # out=outputs
        if(fl==1):
          outputs=outputs.double()
        # compute training reconstruction loss
        train_loss = loss_func(outputs, batch_features)
        
        # compute accumulated gradients
        train_loss.backward()
        
        # perform parameter update based on current gradients
        optimizer.step()
        enc=encoder
        # add the mini-batch training loss to epoch loss
        loss += train_loss.item()
        
        # enc=encoder  
    # compute the epoch training loss
    loss = loss / len(train_dl)
    hist.append(loss)
    
    # display the epoch training loss
    print("epoch : {}/{}, recon loss = {:.8f}".format(epoch + 1, epochs, loss))
  return(enc,hist)

# %%
B_data=np.asarray(B_data,dtype=np.float64)
inputs=torch.from_numpy(B_data)
targets=torch.from_numpy(B_data)

train_dl=givetrain(inputs,targets)

# AE 1 training
encoder,hist1=train_model(400,train_dl,model1,optimizer1,fl=1)
train_dl=givetrain(encoder.detach(),encoder.detach())
print(encoder.detach().shape)

# AE 2 training
encoder,hist2=train_model(300,train_dl,model2,optimizer2)
train_dl=givetrain(encoder.detach(),encoder.detach())
print(encoder.detach().shape)

# AE 3 training
encoder,hist3=train_model(200,train_dl,model3,optimizer3)
train_dl=givetrain(encoder.detach(),encoder.detach())
# print(encoder)
print(encoder.detach().shape)
# Out:
# epoch : 1/400, recon loss = 0.09311881
# epoch : 2/400, recon loss = 0.09100211
# epoch : 3/400, recon loss = 0.08909697
# epoch : 4/400, recon loss = 0.08736630
# epoch : 5/400, recon loss = 0.08577732
# epoch : 6/400, recon loss = 0.08430036
# epoch : 7/400, recon loss = 0.08290878
# epoch : 8/400, recon loss = 0.08157923
# epoch : 9/400, recon loss = 0.08029165
# epoch : 10/400, recon loss = 0.07902920
# epoch : 11/400, recon loss = 0.07777804
# epoch : 12/400, recon loss = 0.07652708
# epoch : 13/400, recon loss = 0.07526781
# epoch : 14/400, recon loss = 0.07399412
# epoch : 15/400, recon loss = 0.07270230
# epoch : 16/400, recon loss = 0.07139103
# epoch : 17/400, recon loss = 0.07006144
# epoch : 18/400, recon loss = 0.06871714
# epoch : 19/400, recon loss = 0.06736411
# epoch : 20/400, recon loss = 0.06601048
# epoch : 21/400, recon loss = 0.06466594
# epoch : 22/400, recon loss = 0.06334094
# epoch : 23/400, recon loss = 0.06204552
# epoch : 24/400, recon loss = 0.06078800
# epoch : 25/400, recon loss = 0.05957394
# epoch : 26/400, recon loss = 0.05840563
# epoch : 27/400, recon loss = 0.05728245
# epoch : 28/400, recon loss = 0.05620192
# epoch : 29/400, recon loss = 0.05516105
# epoch : 30/400, recon loss = 0.05415739
# epoch : 31/400, recon loss = 0.05318958
# epoch : 32/400, recon loss = 0.05225717
# epoch : 33/400, recon loss = 0.05135995
# epoch : 34/400, recon loss = 0.05049739
# epoch : 35/400, recon loss = 0.04966824
# epoch : 36/400, recon loss = 0.04887062
# epoch : 37/400, recon loss = 0.04810248
# epoch : 38/400, recon loss = 0.04736211
# epoch : 39/400, recon loss = 0.04664848
# epoch : 40/400, recon loss = 0.04596137
# epoch : 41/400, recon loss = 0.04530112
# epoch : 42/400, recon loss = 0.04466824
# epoch : 43/400, recon loss = 0.04406313
# epoch : 44/400, recon loss = 0.04348585
# epoch : 45/400, recon loss = 0.04293608
# epoch : 46/400, recon loss = 0.04241320
# epoch : 47/400, recon loss = 0.04191641
# epoch : 48/400, recon loss = 0.04144477
# epoch : 49/400, recon loss = 0.04099729
# epoch : 50/400, recon loss = 0.04057285
# epoch : 51/400, recon loss = 0.04017023
# epoch : 52/400, recon loss = 0.03978806
# epoch : 53/400, recon loss = 0.03942482
# epoch : 54/400, recon loss = 0.03907893
# epoch : 55/400, recon loss = 0.03874885
# epoch : 56/400, recon loss = 0.03843315
# epoch : 57/400, recon loss = 0.03813058
# epoch : 58/400, recon loss = 0.03784009
# epoch : 59/400, recon loss = 0.03756078
# epoch : 60/400, recon loss = 0.03729178
# epoch : 61/400, recon loss = 0.03703221
# epoch : 62/400, recon loss = 0.03678109
# epoch : 63/400, recon loss = 0.03653744
# epoch : 64/400, recon loss = 0.03630029
# epoch : 65/400, recon loss = 0.03606884
# epoch : 66/400, recon loss = 0.03584254
# epoch : 67/400, recon loss = 0.03562108
# epoch : 68/400, recon loss = 0.03540436
# epoch : 69/400, recon loss = 0.03519235
# epoch : 70/400, recon loss = 0.03498496
# epoch : 71/400, recon loss = 0.03478201
# epoch : 72/400, recon loss = 0.03458315
# epoch : 73/400, recon loss = 0.03438791
# epoch : 74/400, recon loss = 0.03419581
# epoch : 75/400, recon loss = 0.03400640
# epoch : 76/400, recon loss = 0.03381933
# epoch : 77/400, recon loss = 0.03363431
# epoch : 78/400, recon loss = 0.03345118
# epoch : 79/400, recon loss = 0.03326978
# epoch : 80/400, recon loss = 0.03308999
# epoch : 81/400, recon loss = 0.03291165
# epoch : 82/400, recon loss = 0.03273465
# epoch : 83/400, recon loss = 0.03255884
# epoch : 84/400, recon loss = 0.03238411
# epoch : 85/400, recon loss = 0.03221036
# epoch : 86/400, recon loss = 0.03203751
# epoch : 87/400, recon loss = 0.03186550
# epoch : 88/400, recon loss = 0.03169428
# epoch : 89/400, recon loss = 0.03152382
# epoch : 90/400, recon loss = 0.03135410
# epoch : 91/400, recon loss = 0.03118509
# epoch : 92/400, recon loss = 0.03101680
# epoch : 93/400, recon loss = 0.03084924
# epoch : 94/400, recon loss = 0.03068241
# epoch : 95/400, recon loss = 0.03051634
# epoch : 96/400, recon loss = 0.03035103
# epoch : 97/400, recon loss = 0.03018649
# epoch : 98/400, recon loss = 0.03002273
# epoch : 99/400, recon loss = 0.02985975
# epoch : 100/400, recon loss = 0.02969757
# epoch : 101/400, recon loss = 0.02953617
# epoch : 102/400, recon loss = 0.02937559
# epoch : 103/400, recon loss = 0.02921584
# epoch : 104/400, recon loss = 0.02905695
# epoch : 105/400, recon loss = 0.02889895
# epoch : 106/400, recon loss = 0.02874188
# epoch : 107/400, recon loss = 0.02858579
# epoch : 108/400, recon loss = 0.02843073
# epoch : 109/400, recon loss = 0.02827677
# epoch : 110/400, recon loss = 0.02812396
# epoch : 111/400, recon loss = 0.02797235
# epoch : 112/400, recon loss = 0.02782199
# epoch : 113/400, recon loss = 0.02767294
# epoch : 114/400, recon loss = 0.02752524
# epoch : 115/400, recon loss = 0.02737893
# epoch : 116/400, recon loss = 0.02723404
# epoch : 117/400, recon loss = 0.02709059
# epoch : 118/400, recon loss = 0.02694859
# epoch : 119/400, recon loss = 0.02680806
# epoch : 120/400, recon loss = 0.02666897
# epoch : 121/400, recon loss = 0.02653129
# epoch : 122/400, recon loss = 0.02639501
# epoch : 123/400, recon loss = 0.02626006
# epoch : 124/400, recon loss = 0.02612642
# epoch : 125/400, recon loss = 0.02599402
# epoch : 126/400, recon loss = 0.02586281
# epoch : 127/400, recon loss = 0.02573274
# epoch : 128/400, recon loss = 0.02560375
# epoch : 129/400, recon loss = 0.02547579
# epoch : 130/400, recon loss = 0.02534880
# epoch : 131/400, recon loss = 0.02522275
# epoch : 132/400, recon loss = 0.02509760
# epoch : 133/400, recon loss = 0.02497329
# epoch : 134/400, recon loss = 0.02484982
# epoch : 135/400, recon loss = 0.02472714
# epoch : 136/400, recon loss = 0.02460524
# epoch : 137/400, recon loss = 0.02448410
# epoch : 138/400, recon loss = 0.02436371
# epoch : 139/400, recon loss = 0.02424405
# epoch : 140/400, recon loss = 0.02412513
# epoch : 141/400, recon loss = 0.02400694
# epoch : 142/400, recon loss = 0.02388946
# epoch : 143/400, recon loss = 0.02377271
# epoch : 144/400, recon loss = 0.02365667
# epoch : 145/400, recon loss = 0.02354133
# epoch : 146/400, recon loss = 0.02342670
# epoch : 147/400, recon loss = 0.02331276
# epoch : 148/400, recon loss = 0.02319950
# epoch : 149/400, recon loss = 0.02308690
# epoch : 150/400, recon loss = 0.02297496
# epoch : 151/400, recon loss = 0.02286364
# epoch : 152/400, recon loss = 0.02275295
# epoch : 153/400, recon loss = 0.02264286
# epoch : 154/400, recon loss = 0.02253335
# epoch : 155/400, recon loss = 0.02242442
# epoch : 156/400, recon loss = 0.02231607
# epoch : 157/400, recon loss = 0.02220827
# epoch : 158/400, recon loss = 0.02210104
# epoch : 159/400, recon loss = 0.02199437
# epoch : 160/400, recon loss = 0.02188828
# epoch : 161/400, recon loss = 0.02178277
# epoch : 162/400, recon loss = 0.02167788
# epoch : 163/400, recon loss = 0.02157361
# epoch : 164/400, recon loss = 0.02147000
# epoch : 165/400, recon loss = 0.02136708
# epoch : 166/400, recon loss = 0.02126489
# epoch : 167/400, recon loss = 0.02116346
# epoch : 168/400, recon loss = 0.02106282
# epoch : 169/400, recon loss = 0.02096304
# epoch : 170/400, recon loss = 0.02086414
# epoch : 171/400, recon loss = 0.02076617
# epoch : 172/400, recon loss = 0.02066917
# epoch : 173/400, recon loss = 0.02057317
# epoch : 174/400, recon loss = 0.02047823
# epoch : 175/400, recon loss = 0.02038435
# epoch : 176/400, recon loss = 0.02029157
# epoch : 177/400, recon loss = 0.02019991
# epoch : 178/400, recon loss = 0.02010937
# epoch : 179/400, recon loss = 0.02001995
# epoch : 180/400, recon loss = 0.01993166
# epoch : 181/400, recon loss = 0.01984447
# epoch : 182/400, recon loss = 0.01975837
# epoch : 183/400, recon loss = 0.01967333
# epoch : 184/400, recon loss = 0.01958932
# epoch : 185/400, recon loss = 0.01950629
# epoch : 186/400, recon loss = 0.01942422
# epoch : 187/400, recon loss = 0.01934307
# epoch : 188/400, recon loss = 0.01926279
# epoch : 189/400, recon loss = 0.01918337
# epoch : 190/400, recon loss = 0.01910475
# epoch : 191/400, recon loss = 0.01902693
# epoch : 192/400, recon loss = 0.01894987
# epoch : 193/400, recon loss = 0.01887356
# epoch : 194/400, recon loss = 0.01879798
# epoch : 195/400, recon loss = 0.01872312
# epoch : 196/400, recon loss = 0.01864897
# epoch : 197/400, recon loss = 0.01857553
# epoch : 198/400, recon loss = 0.01850277
# epoch : 199/400, recon loss = 0.01843071
# epoch : 200/400, recon loss = 0.01835932
# epoch : 201/400, recon loss = 0.01828861
# epoch : 202/400, recon loss = 0.01821855
# epoch : 203/400, recon loss = 0.01814913
# epoch : 204/400, recon loss = 0.01808035
# epoch : 205/400, recon loss = 0.01801218
# epoch : 206/400, recon loss = 0.01794462
# epoch : 207/400, recon loss = 0.01787763
# epoch : 208/400, recon loss = 0.01781122
# epoch : 209/400, recon loss = 0.01774535
# epoch : 210/400, recon loss = 0.01768001
# epoch : 211/400, recon loss = 0.01761518
# epoch : 212/400, recon loss = 0.01755085
# epoch : 213/400, recon loss = 0.01748699
# epoch : 214/400, recon loss = 0.01742360
# epoch : 215/400, recon loss = 0.01736066
# epoch : 216/400, recon loss = 0.01729815
# epoch : 217/400, recon loss = 0.01723605
# epoch : 218/400, recon loss = 0.01717436
# epoch : 219/400, recon loss = 0.01711306
# epoch : 220/400, recon loss = 0.01705213
# epoch : 221/400, recon loss = 0.01699157
# epoch : 222/400, recon loss = 0.01693135
# epoch : 223/400, recon loss = 0.01687148
# epoch : 224/400, recon loss = 0.01681192
# epoch : 225/400, recon loss = 0.01675267
# epoch : 226/400, recon loss = 0.01669372
# epoch : 227/400, recon loss = 0.01663504
# epoch : 228/400, recon loss = 0.01657663
# epoch : 229/400, recon loss = 0.01651847
# epoch : 230/400, recon loss = 0.01646054
# epoch : 231/400, recon loss = 0.01640283
# epoch : 232/400, recon loss = 0.01634533
# epoch : 233/400, recon loss = 0.01628802
# epoch : 234/400, recon loss = 0.01623089
# epoch : 235/400, recon loss = 0.01617394
# epoch : 236/400, recon loss = 0.01611714
# epoch : 237/400, recon loss = 0.01606050
# epoch : 238/400, recon loss = 0.01600400
# epoch : 239/400, recon loss = 0.01594764
# epoch : 240/400, recon loss = 0.01589142
# epoch : 241/400, recon loss = 0.01583535
# epoch : 242/400, recon loss = 0.01577941
# epoch : 243/400, recon loss = 0.01572361
# epoch : 244/400, recon loss = 0.01566796
# epoch : 245/400, recon loss = 0.01561246
# epoch : 246/400, recon loss = 0.01555713
# epoch : 247/400, recon loss = 0.01550197
# epoch : 248/400, recon loss = 0.01544699
# epoch : 249/400, recon loss = 0.01539220
# epoch : 250/400, recon loss = 0.01533761
# epoch : 251/400, recon loss = 0.01528323
# epoch : 252/400, recon loss = 0.01522907
# epoch : 253/400, recon loss = 0.01517514
# epoch : 254/400, recon loss = 0.01512145
# epoch : 255/400, recon loss = 0.01506799
# epoch : 256/400, recon loss = 0.01501478
# epoch : 257/400, recon loss = 0.01496181
# epoch : 258/400, recon loss = 0.01490908
# epoch : 259/400, recon loss = 0.01485659
# epoch : 260/400, recon loss = 0.01480434
# epoch : 261/400, recon loss = 0.01475231
# epoch : 262/400, recon loss = 0.01470050
# epoch : 263/400, recon loss = 0.01464890
# epoch : 264/400, recon loss = 0.01459750
# epoch : 265/400, recon loss = 0.01454629
# epoch : 266/400, recon loss = 0.01449527
# epoch : 267/400, recon loss = 0.01444441
# epoch : 268/400, recon loss = 0.01439371
# epoch : 269/400, recon loss = 0.01434318
# epoch : 270/400, recon loss = 0.01429279
# epoch : 271/400, recon loss = 0.01424255
# epoch : 272/400, recon loss = 0.01419246
# epoch : 273/400, recon loss = 0.01414251
# epoch : 274/400, recon loss = 0.01409271
# epoch : 275/400, recon loss = 0.01404306
# epoch : 276/400, recon loss = 0.01399356
# epoch : 277/400, recon loss = 0.01394423
# epoch : 278/400, recon loss = 0.01389505
# epoch : 279/400, recon loss = 0.01384606
# epoch : 280/400, recon loss = 0.01379724
# epoch : 281/400, recon loss = 0.01374861
# epoch : 282/400, recon loss = 0.01370017
# epoch : 283/400, recon loss = 0.01365194
# epoch : 284/400, recon loss = 0.01360393
# epoch : 285/400, recon loss = 0.01355613
# epoch : 286/400, recon loss = 0.01350857
# epoch : 287/400, recon loss = 0.01346124
# epoch : 288/400, recon loss = 0.01341416
# epoch : 289/400, recon loss = 0.01336732
# epoch : 290/400, recon loss = 0.01332075
# epoch : 291/400, recon loss = 0.01327444
# epoch : 292/400, recon loss = 0.01322841
# epoch : 293/400, recon loss = 0.01318265
# epoch : 294/400, recon loss = 0.01313717
# epoch : 295/400, recon loss = 0.01309198
# epoch : 296/400, recon loss = 0.01304708
# epoch : 297/400, recon loss = 0.01300247
# epoch : 298/400, recon loss = 0.01295816
# epoch : 299/400, recon loss = 0.01291414
# epoch : 300/400, recon loss = 0.01287042
# epoch : 301/400, recon loss = 0.01282700
# epoch : 302/400, recon loss = 0.01278387
# epoch : 303/400, recon loss = 0.01274103
# epoch : 304/400, recon loss = 0.01269848
# epoch : 305/400, recon loss = 0.01265622
# epoch : 306/400, recon loss = 0.01261424
# epoch : 307/400, recon loss = 0.01257253
# epoch : 308/400, recon loss = 0.01253110
# epoch : 309/400, recon loss = 0.01248993
# epoch : 310/400, recon loss = 0.01244902
# epoch : 311/400, recon loss = 0.01240836
# epoch : 312/400, recon loss = 0.01236795
# epoch : 313/400, recon loss = 0.01232777
# epoch : 314/400, recon loss = 0.01228783
# epoch : 315/400, recon loss = 0.01224812
# epoch : 316/400, recon loss = 0.01220863
# epoch : 317/400, recon loss = 0.01216935
# epoch : 318/400, recon loss = 0.01213028
# epoch : 319/400, recon loss = 0.01209141
# epoch : 320/400, recon loss = 0.01205272
# epoch : 321/400, recon loss = 0.01201423
# epoch : 322/400, recon loss = 0.01197591
# epoch : 323/400, recon loss = 0.01193775
# epoch : 324/400, recon loss = 0.01189976
# epoch : 325/400, recon loss = 0.01186193
# epoch : 326/400, recon loss = 0.01182423
# epoch : 327/400, recon loss = 0.01178668
# epoch : 328/400, recon loss = 0.01174925
# epoch : 329/400, recon loss = 0.01171195
# epoch : 330/400, recon loss = 0.01167476
# epoch : 331/400, recon loss = 0.01163767
# epoch : 332/400, recon loss = 0.01160069
# epoch : 333/400, recon loss = 0.01156381
# epoch : 334/400, recon loss = 0.01152701
# epoch : 335/400, recon loss = 0.01149031
# epoch : 336/400, recon loss = 0.01145368
# epoch : 337/400, recon loss = 0.01141713
# epoch : 338/400, recon loss = 0.01138065
# epoch : 339/400, recon loss = 0.01134424
# epoch : 340/400, recon loss = 0.01130791
# epoch : 341/400, recon loss = 0.01127163
# epoch : 342/400, recon loss = 0.01123543
# epoch : 343/400, recon loss = 0.01119929
# epoch : 344/400, recon loss = 0.01116321
# epoch : 345/400, recon loss = 0.01112720
# epoch : 346/400, recon loss = 0.01109125
# epoch : 347/400, recon loss = 0.01105536
# epoch : 348/400, recon loss = 0.01101954
# epoch : 349/400, recon loss = 0.01098379
# epoch : 350/400, recon loss = 0.01094811
# epoch : 351/400, recon loss = 0.01091249
# epoch : 352/400, recon loss = 0.01087695
# epoch : 353/400, recon loss = 0.01084147
# epoch : 354/400, recon loss = 0.01080608
# epoch : 355/400, recon loss = 0.01077076
# epoch : 356/400, recon loss = 0.01073552
# epoch : 357/400, recon loss = 0.01070037
# epoch : 358/400, recon loss = 0.01066530
# epoch : 359/400, recon loss = 0.01063032
# epoch : 360/400, recon loss = 0.01059544
# epoch : 361/400, recon loss = 0.01056065
# epoch : 362/400, recon loss = 0.01052596
# epoch : 363/400, recon loss = 0.01049138
# epoch : 364/400, recon loss = 0.01045691
# epoch : 365/400, recon loss = 0.01042255
# epoch : 366/400, recon loss = 0.01038831
# epoch : 367/400, recon loss = 0.01035419
# epoch : 368/400, recon loss = 0.01032021
# epoch : 369/400, recon loss = 0.01028637
# epoch : 370/400, recon loss = 0.01025267
# epoch : 371/400, recon loss = 0.01021913
# epoch : 372/400, recon loss = 0.01018574
# epoch : 373/400, recon loss = 0.01015252
# epoch : 374/400, recon loss = 0.01011948
# epoch : 375/400, recon loss = 0.01008663
# epoch : 376/400, recon loss = 0.01005396
# epoch : 377/400, recon loss = 0.01002150
# epoch : 378/400, recon loss = 0.00998925
# epoch : 379/400, recon loss = 0.00995722
# epoch : 380/400, recon loss = 0.00992541
# epoch : 381/400, recon loss = 0.00989383
# epoch : 382/400, recon loss = 0.00986250
# epoch : 383/400, recon loss = 0.00983140
# epoch : 384/400, recon loss = 0.00980056
# epoch : 385/400, recon loss = 0.00976997
# epoch : 386/400, recon loss = 0.00973963
# epoch : 387/400, recon loss = 0.00970955
# epoch : 388/400, recon loss = 0.00967973
# epoch : 125/300, recon loss = 0.06094603
# epoch : 126/300, recon loss = 0.06067587
# epoch : 127/300, recon loss = 0.06041006
# epoch : 128/300, recon loss = 0.06014845
# epoch : 129/300, recon loss = 0.05989087
# epoch : 130/300, recon loss = 0.05963719
# epoch : 131/300, recon loss = 0.05938724
# epoch : 132/300, recon loss = 0.05914089
# epoch : 133/300, recon loss = 0.05889798
# epoch : 134/300, recon loss = 0.05865838
# epoch : 135/300, recon loss = 0.05842195
# epoch : 136/300, recon loss = 0.05818855
# epoch : 137/300, recon loss = 0.05795806
# epoch : 138/300, recon loss = 0.05773035
# epoch : 139/300, recon loss = 0.05750531
# epoch : 140/300, recon loss = 0.05728283
# epoch : 141/300, recon loss = 0.05706281
# epoch : 142/300, recon loss = 0.05684516
# epoch : 143/300, recon loss = 0.05662980
# epoch : 144/300, recon loss = 0.05641665
# epoch : 145/300, recon loss = 0.05620563
# epoch : 146/300, recon loss = 0.05599672
# epoch : 147/300, recon loss = 0.05578988
# epoch : 148/300, recon loss = 0.05558504
# epoch : 149/300, recon loss = 0.05538219
# epoch : 150/300, recon loss = 0.05518132
# epoch : 151/300, recon loss = 0.05498241
# epoch : 152/300, recon loss = 0.05478546
# epoch : 153/300, recon loss = 0.05459045
# epoch : 154/300, recon loss = 0.05439738
# epoch : 155/300, recon loss = 0.05420626
# epoch : 156/300, recon loss = 0.05401707
# epoch : 157/300, recon loss = 0.05382980
# epoch : 158/300, recon loss = 0.05364443
# epoch : 159/300, recon loss = 0.05346093
# epoch : 160/300, recon loss = 0.05327930
# epoch : 161/300, recon loss = 0.05309946
# epoch : 162/300, recon loss = 0.05292141
# epoch : 163/300, recon loss = 0.05274507
# epoch : 164/300, recon loss = 0.05257040
# epoch : 165/300, recon loss = 0.05239734
# epoch : 166/300, recon loss = 0.05222584
# epoch : 167/300, recon loss = 0.05205584
# epoch : 168/300, recon loss = 0.05188728
# epoch : 169/300, recon loss = 0.05172011
# epoch : 170/300, recon loss = 0.05155428
# epoch : 171/300, recon loss = 0.05138974
# epoch : 172/300, recon loss = 0.05122645
# epoch : 173/300, recon loss = 0.05106438
# epoch : 174/300, recon loss = 0.05090350
# epoch : 175/300, recon loss = 0.05074378
# epoch : 176/300, recon loss = 0.05058520
# epoch : 177/300, recon loss = 0.05042773
# epoch : 178/300, recon loss = 0.05027137
# epoch : 179/300, recon loss = 0.05011609
# epoch : 180/300, recon loss = 0.04996187
# epoch : 181/300, recon loss = 0.04980870
# epoch : 182/300, recon loss = 0.04965655
# epoch : 183/300, recon loss = 0.04950540
# epoch : 184/300, recon loss = 0.04935522
# epoch : 185/300, recon loss = 0.04920598
# epoch : 186/300, recon loss = 0.04905766
# epoch : 187/300, recon loss = 0.04891019
# epoch : 188/300, recon loss = 0.04876357
# epoch : 189/300, recon loss = 0.04861773
# epoch : 190/300, recon loss = 0.04847265
# epoch : 191/300, recon loss = 0.04832828
# epoch : 192/300, recon loss = 0.04818458
# epoch : 193/300, recon loss = 0.04804151
# epoch : 168/200, recon loss = 0.07941805
# epoch : 169/200, recon loss = 0.07909103
# epoch : 170/200, recon loss = 0.07877032
# epoch : 171/200, recon loss = 0.07845581
# epoch : 172/200, recon loss = 0.07814742
# epoch : 173/200, recon loss = 0.07784504
# epoch : 174/200, recon loss = 0.07754856
# epoch : 175/200, recon loss = 0.07725784
# epoch : 176/200, recon loss = 0.07697280
# epoch : 177/200, recon loss = 0.07669325
# epoch : 178/200, recon loss = 0.07641906
# epoch : 179/200, recon loss = 0.07615010
# epoch : 180/200, recon loss = 0.07588618
# epoch : 181/200, recon loss = 0.07562716
# epoch : 182/200, recon loss = 0.07537287
# epoch : 183/200, recon loss = 0.07512317
# epoch : 184/200, recon loss = 0.07487787
# epoch : 185/200, recon loss = 0.07463681
# epoch : 186/200, recon loss = 0.07439984
# epoch : 187/200, recon loss = 0.07416679
# epoch : 188/200, recon loss = 0.07393751
# epoch : 189/200, recon loss = 0.07371185
# epoch : 190/200, recon loss = 0.07348964
# epoch : 191/200, recon loss = 0.07327074
# epoch : 192/200, recon loss = 0.07305498
# epoch : 193/200, recon loss = 0.07284226
# epoch : 194/200, recon loss = 0.07263239
# epoch : 195/200, recon loss = 0.07242527
# epoch : 196/200, recon loss = 0.07222074
# epoch : 197/200, recon loss = 0.07201869
# epoch : 198/200, recon loss = 0.07181899
# epoch : 199/200, recon loss = 0.07162151
# epoch : 200/200, recon loss = 0.07142612
# torch.Size([115, 16])

# %%
plt.plot(hist1,label='autoencoder 1',color='r')
plt.legend()
plt.show()
plt.plot(hist2,label='autoencoder 2',color='b')
plt.legend()
plt.show()
plt.plot(hist3,label='autoencoder 3',color='y')
plt.legend()
plt.show()

# %%
B_data_X=encoder.detach().numpy()

# %%
kmeans = KMeans(n_clusters=12,init='k-means++',random_state=1295)
kmeans.fit(B_data_X)
X_ae = kmeans.labels_
#---------------------------------------------------------|Ground Truth|-------
c_attributes = nx.get_node_attributes(G_data,'value')
c_groups = []

for i, val in enumerate(c_attributes.values()):
    c_groups.append(val)     
X_gt = np.array(c_groups)
print(X_ae)
print(X_gt)
metrics.normalized_mutual_info_score(X_gt, X_ae, average_method='arithmetic')
# Out:
# [11  3  1  6 11  6  1  5  5 11  6  2  0  1  0  1 11  4  0  7  4  5  5 11
#   8  3  0  4  8  7  7  0  1  3  0  7  0  3  0  1  6 11  0  0  9  3 10  1
#   9 10  8  5  6 10  0  7  4  9  2  2  1  0  4  2  1  4  9 10  5  8  4  0
#   6 10  6  9  4  5  5  7  7  6  7 10  6  0  9  4 10  3  8  9  9 11  7  4
#   4  2  6  0  1  7  6  3 11  3  1  6  5  3 10  5  9  4 10]
# [ 7  0  2  3  7  3  2  8  8  7  3 10  6  2  6  2  7  9  6  1  9  8  8  7
#  10  0  6  9 11  1  1  6  2  0  6  1  5  0  6  2  3  7  5  6  4  0 11  2
#   4 11 10  8  3 11  6  1  9  4 11 10  2  6  9 10  2  9  4 11  8 10  9  6
#   3 11  3  4  9  8  8  1  5  3  5 11  3  6  4  9 11  0  5  4  4  7  1  9
#   9 10  3  6  2  1  3  0  7  0  2  3  8  0  4  8  4  9 11]
# 0.9272628615575594

# %%
max=0
index_max=0
for value in range(0,2000):
    kmeans = KMeans(n_clusters=12,random_state=value,init='k-means++')
    kmeans.fit(B_data_X)
    X_ae = kmeans.labels_
    #---------------------------------------------------------|Ground Truth|-------
    c_attributes = nx.get_node_attributes(G_data,'value')
    c_groups = []

    for i, val in enumerate(c_attributes.values()):
        c_groups.append(val)      
   
    X_gt = np.array(c_groups)
    temp=metrics.normalized_mutual_info_score(X_gt, X_ae, average_method='arithmetic')
    if(temp>max):
        max=temp
        index_max=value
    if(value%100==0):
        print(index_max,max)
print("Final result:",index_max,max)
# Out:
# 0 0.8873885903620813
# 24 0.9169571911234266
# 166 0.9248993884606711
# 166 0.9248993884606711
# 166 0.9248993884606711
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 420 0.9272628615575593
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# 1295 0.9272628615575594
# Final result: 1295 0.9272628615575594

# %%
G=G_data
kmeans = KMeans(init='k-means++',n_clusters=12,random_state=index_max)
kmeans.fit(B_data_X)
X_ae = kmeans.labels_
labels_dict={}
for index,item in enumerate(X_ae):
    labels_dict[item]=[]
for index,item in enumerate(X_ae):
    labels_dict[item].append(list(G.nodes)[index])
print(labels_dict)
# Out:
# {11: ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'Wyoming', 'Utah', 'ColoradoState', 'AirForce', 'NevadaLasVegas'], 3: ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland'], 1: ['Iowa', 'PennState', 'Northwestern', 'Wisconsin', 'Michigan', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana'], 6: ['KansasState', 'TexasTech', 'Baylor', 'Colorado', 'Kansas', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'Texas', 'Missouri', 'OklahomaState'], 5: ['SouthernCalifornia', 'ArizonaState', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California'], 2: ['NorthTexas', 'LouisianaTech', 'LouisianaMonroe', 'MiddleTennesseeState', 'LouisianaLafayette'], 0: ['NorthernIllinois', 'WesternMichigan', 'Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralFlorida', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'MiamiOhio', 'Ohio', 'Toledo', 'Marshall'], 4: ['Auburn', 'Alabama', 'Florida', 'Kentucky', 'Vanderbilt', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'Arkansas'], 7: ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Rutgers', 'MiamiFlorida'], 8: ['ArkansasState', 'BoiseState', 'Idaho', 'NewMexicoState', 'UtahState'], 9: ['EastCarolina', 'Houston', 'Louisville', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Cincinnati', 'AlabamaBirmingham'], 10: ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']}

# %%
G=G_data
pos=nx.spring_layout(G)
colors=['#f20905','#ab7533','#de9c0d','#a5e841','#09ed7b','#0af0e0','#0f5ea8','#08046e','#9c2be3','#e607c4','#e607c4','#0a0105']
fig= plt.figure(figsize=(15,10))
for key,col in enumerate(labels_dict):
    nx.draw(G,pos,nodelist=labels_dict[key],node_color=colors[col],edge_color='#3b3b3b',node_size=300,width=0.2)

plt.title('Football')
plt.show()
